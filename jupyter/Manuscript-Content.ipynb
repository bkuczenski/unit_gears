# %%
from itertools import chain
import pandas as pd
from collections import defaultdict

from math import floor, ceil, log10
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
model_params_xlsx = "model_parameters_rev.xlsx"
fig_title = 'fishing gear-rev'

# %%
import sys
import os
ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(ROOT)

# %%
from unit_gears.model_library import GearModelLibrary, validate_gear_types
from unit_gears.gear_mapping import gear_mapper

# %%
gml = GearModelLibrary(os.path.join(ROOT, 'models'), verbose=True)
# Out:
# Adding effort model Life Cycle Inventory - Landed Catch
# Adding effort model Fuel Economy - Sendai Bay small scale trawl
# Adding effort model Fishing Days by vessel size - Sendai Bay small scale trawl
# Adding gear intensity model small scale bottom trawl - Sendai Bay
# Adding dissipation model Gilman prioritization - Drift gillnet
# Adding dissipation model Gilman prioritization - Set and fixed gillnet
# Adding dissipation model Gilman prioritization - Purse seine Non-tuna
# Adding dissipation model Gilman prioritization - Purse seine Tuna
# Adding dissipation model Gilman prioritization - Beach Seine
# Adding dissipation model Gilman prioritization - Boat Seine net
# Adding dissipation model Gilman prioritization - Midwater trawl
# Adding dissipation model Gilman prioritization - Bottom trawl
# Adding dissipation model Gilman prioritization - Pots
# Adding dissipation model Gilman prioritization - Fyke net
# Adding dissipation model Gilman prioritization - Pound net
# Adding dissipation model Gilman prioritization - Tuna purse seine drifting FAD
# Adding dissipation model Gilman prioritization - Tuna purse seine anchored FAD
# Adding dissipation model Gilman prioritization - Pole-and-line anchored FAD
# Adding dissipation model Gilman prioritization - Pelagic longline
# Adding dissipation model Gilman prioritization - Demersal longline and trotline
# Adding dissipation model Gilman prioritization - Handline, surface, midwater and bottom
# Adding dissipation model Gilman prioritization - Troll
# Adding dissipation model Gilman prioritization - Pole-and-line
# Adding effort model Effort intensity for 27.5x5 m gillnets in terms of square-meter-hours
# Adding gear intensity model Gear intensity for 200-mm mesh 0.7mm dia monofilament gillnets
# Adding gear intensity model Vessel length to seine weight
# Adding gear intensity model Engine size to seine weight
# Adding dissipation model Norway - Trawls - Lost to ocean
# Adding dissipation model Norway - Purse Seine - Lost to ocean
# Adding dissipation model Norway - Danish Seine - Lost to ocean
# Adding dissipation model Norway - Gillnets - Lost to ocean
# Adding dissipation model Norway - Longlines - Lost to ocean
# Adding dissipation model Norway - Pots/Traps - Lost to ocean
# Adding gear intensity model Small scale - vessel length to gear weight
# Adding effort model Turkish driftnet CPUE
# Adding gear intensity model Turkish driftnet intensity
# Adding effort model Fishing hours - Landed catch - Chesapeake small scale trawl
# Adding effort model Effort intensity 4000-4500 hook longline vessels
# Adding gear intensity model Gear intensity for Thuunus alalunga Mediterranean longline
# Adding gear intensity model Trawl meta-model - Mediterranean - Gross Tonnage
# Adding gear intensity model Trawl meta-model - Mediterranean - Engine Power
# Adding gear intensity model Trawl meta-model - Mediterranean - Length Overall
# Adding gear intensity model Trawl meta-model - Mediterranean - Length of Head Line
# Adding gear intensity model purse seine LCI - Cantabria Anchovy
# Adding effort model Landed Catch by engine capacity- Croatian Purse Seine
# Adding effort model Landed Catch by vessel LOA- Croatian Purse Seine
# Adding effort model Landed Catch by gross tonnage- Croatian Purse Seine
# Adding gear intensity model purse seine LCI - Peru Anchoveta

# %%
sein = list(gml.valid_models({'GFWCategory': 'seiners'}))
trwl = list(gml.valid_models({'GFWCategory': 'trawlers'}))
pasv = list(gml.valid_models({"GilmanGear25Code": "GNS"})) + list(gml.valid_models({"GilmanGear25Code": "LLP"})) + list(gml.valid_models({"FAOGearAbbrev": "GND"}))
# Out:
# 0: CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] passed
# 1: CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] passed
# 2: CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] passed
# 3: CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] passed
# 4: CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# 5: CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by engine capacity- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by gross tonnage- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Vessel length in meters > ['Kilowatt of engine capacity']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Vessel length in meters > ['Kilowatt of engine capacity']
# 6: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] passed
# 7: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] passed
# 8: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] passed
# 9: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] passed
# 10: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# 11: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# 12: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] passed
# 13: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] passed
# 14: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] passed
# 15: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] passed
# 16: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# 17: CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Landed Catch by vessel LOA- Croatian Purse Seine: 0d)[Soldo 2019]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Vessel length in meters > ['Effort for one tonne landed catch']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Kilowatt of engine capacity']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Kilowatt of engine capacity']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Kilowatt of engine capacity']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Kilowatt of engine capacity']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Kilowatt of engine capacity']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Engine size to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Kilowatt of engine capacity']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Small scale - vessel length to gear weight: 0c)[Laissane 2011]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Vessel length to seine weight: 0c)[Pravin 2016]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# 18: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] passed
# 19: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] passed
# 20: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] passed
# 21: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] passed
# 22: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# 23: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Cantabria Anchovy: 0c)[Laso 2017]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# 24: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Beach Seine: 0c)[Gilman 2021] passed
# 25: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Boat Seine net: 0c)[Gilman 2021] passed
# 26: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Purse seine Non-tuna: 0c)[Gilman 2021] passed
# 27: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Gilman prioritization - Purse seine Tuna: 0c)[Gilman 2021] passed
# 28: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Norway - Danish Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# 29: CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(purse seine LCI - Peru Anchoveta: 0d)[Avadi 2014]-Dissipation(Norway - Purse Seine - Lost to ocean: 0c)[Deshpande 2020] passed
# CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Kilowatt of engine capacity']
# CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Kilowatt of engine capacity']
# CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Kilowatt of engine capacity']
# 0: CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] passed
# 1: CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] passed
# 2: CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] passed
# CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Vessel length in meters']
# CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Length of line']
# CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Length of line']
# CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Gross Tonnage of vessel > ['Length of line']
# 3: CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] passed
# 4: CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] passed
# 5: CatchEffort(Fishing Days by vessel size - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] passed
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: ['Fishing hour'] > ['Year of operation']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: ['Fishing hour'] > ['Year of operation']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: ['Fishing hour'] > ['Gear lifetime', 'Year of operation']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Length of line']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Length of line']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Length of line']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fishing hours - Landed catch - Chesapeake small scale trawl: 0c)[Hoffman 2009]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# 6: CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] passed
# 7: CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] passed
# 8: CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] passed
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Vessel length in meters']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Length of line']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Length of line']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Length of line']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Fuel Economy - Sendai Bay small scale trawl: 0c)[Watanabe 2016]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Kilowatt of engine capacity > ['Gross Tonnage of vessel']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Kilowatt of engine capacity']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Kilowatt of engine capacity']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Engine Power: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Kilowatt of engine capacity']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Gross Tonnage of vessel']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Gross Tonnage of vessel']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Gross Tonnage: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Gross Tonnage of vessel']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Length Overall: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Length of line']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Length of line']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Trawl meta-model - Mediterranean - Length of Head Line: 0d)[Sala 2019]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Length of line']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Gilman prioritization - Bottom trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Gross Tonnage of vessel']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Gilman prioritization - Midwater trawl: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Gross Tonnage of vessel']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(small scale bottom trawl - Sendai Bay: 0c)[Watanabe 2016]-Dissipation(Norway - Trawls - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Gross Tonnage of vessel']
# 0: CatchEffort(Effort intensity for 27.5x5 m gillnets in terms of square-meter-hours: 0c)[Grimaldo 2019]-GearIntensity(Gear intensity for 200-mm mesh 0.7mm dia monofilament gillnets: 0c)[Grimaldo 2019]-Dissipation(Gilman prioritization - Set and fixed gillnet: 0c)[Gilman 2021] passed
# 1: CatchEffort(Effort intensity for 27.5x5 m gillnets in terms of square-meter-hours: 0c)[Grimaldo 2019]-GearIntensity(Gear intensity for 200-mm mesh 0.7mm dia monofilament gillnets: 0c)[Grimaldo 2019]-Dissipation(Norway - Gillnets - Lost to ocean: 0c)[Deshpande 2020] passed
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Gear intensity for 200-mm mesh 0.7mm dia monofilament gillnets: 0c)[Grimaldo 2019]-Dissipation(Gilman prioritization - Set and fixed gillnet: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Square meter of net']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Gear intensity for 200-mm mesh 0.7mm dia monofilament gillnets: 0c)[Grimaldo 2019]-Dissipation(Norway - Gillnets - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Square meter of net']
# 0: CatchEffort(Effort intensity 4000-4500 hook longline vessels: 0d)[Gabr 2012]-GearIntensity(Gear intensity for Thuunus alalunga Mediterranean longline: 0c)[Gabr 2012]-Dissipation(Gilman prioritization - Pelagic longline: 0c)[Gilman 2021] passed
# 1: CatchEffort(Effort intensity 4000-4500 hook longline vessels: 0d)[Gabr 2012]-GearIntensity(Gear intensity for Thuunus alalunga Mediterranean longline: 0c)[Gabr 2012]-Dissipation(Norway - Longlines - Lost to ocean: 0c)[Deshpande 2020] passed
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Gear intensity for Thuunus alalunga Mediterranean longline: 0c)[Gabr 2012]-Dissipation(Gilman prioritization - Pelagic longline: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters', 'Kilowatt of engine capacity', 'Number of hooks']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Gear intensity for Thuunus alalunga Mediterranean longline: 0c)[Gabr 2012]-Dissipation(Norway - Longlines - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters', 'Kilowatt of engine capacity', 'Number of hooks']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Turkish driftnet intensity: 0c)[Akyol 2012]-Dissipation(Gilman prioritization - Drift gillnet: 0c)[Gilman 2021] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters', 'Gross Tonnage of vessel', 'Kilowatt of engine capacity', 'kilometer of net']
# CatchEffort(Life Cycle Inventory - Landed Catch: 0c)[LCI Model]-GearIntensity(Turkish driftnet intensity: 0c)[Akyol 2012]-Dissipation(Norway - Gillnets - Lost to ocean: 0c)[Deshpande 2020] ... failed ConflictingUnits: Effort for one tonne landed catch > ['Vessel length in meters', 'Gross Tonnage of vessel', 'Kilowatt of engine capacity', 'kilometer of net']
# 0: CatchEffort(Turkish driftnet CPUE: 0c)[Akyol 2012]-GearIntensity(Turkish driftnet intensity: 0c)[Akyol 2012]-Dissipation(Gilman prioritization - Drift gillnet: 0c)[Gilman 2021] passed
# 1: CatchEffort(Turkish driftnet CPUE: 0c)[Akyol 2012]-GearIntensity(Turkish driftnet intensity: 0c)[Akyol 2012]-Dissipation(Norway - Gillnets - Lost to ocean: 0c)[Deshpande 2020] passed

# %%
len(sein)
# Out:
# 30

# %%
len(trwl)
# Out:
# 9

# %%
len(pasv)
# Out:
# 6

# %%
for p in pasv:
    lbl = next(next(gear_mapper.equivs(k, v) for k, v in p._e.gear_types.items()))['GilmanGear25Description']
    p.label = lbl + '-' + p.family[2]

# %%
models = [('Seiners', sein), ('Trawlers', trwl), ('Passive Gear', pasv)]

# %%
def write_models(mod_list, xlsfile=model_params_xlsx):
    xlw = pd.ExcelWriter(xlsfile)
    for name, arg in mod_list:
        df = pd.DataFrame(list(chain(*[k.report() for k in arg])))
        df.to_excel(xlw, sheet_name=name)
    xlw.save()

# %%
write_models(models)

# %%
# Run Monte Carlo simulation
results = []
for name, arg in models:
    _r = defaultdict(list)
    for m in arg:
        _r[m.label].extend([m.sample() for i in range(1000)])
    results.append((name, _r))

# %%
def make_polyhist(ax, dat, title='fishing gear'):
    
    for k, v in dat.items():
        rat = max(v) / min(v)
        nbins = floor(40*log10(rat))
        #nbins=40
        _, b = np.histogram(v, nbins)
        logbins = np.logspace(np.log10(b[0]),np.log10(b[-1]),len(b))

        plt.hist(v, bins=logbins, alpha=0.7, label=k)
    ax.set_yticks([])
    ax.set_xscale('log')
    #ax.set_xlabel('Gear dissipation (kg/t catch)')
    ax.set_ylabel('')
    ax.set_title(title)
    ax.legend(fontsize=8)
    
def make_gear_model_plot(res, title=fig_title, savefig=True, bind_min=1e-8, bind_max=1e2):
    n = len(res)
    fig = plt.figure(figsize=(10,3 * n))
    min_x = None
    max_x = None
    axs = []
    for i in range(len(res)):
        name, _r = res[i]
        ax = fig.add_subplot(3,1,i+1)
        axs.append(ax)
        make_polyhist(ax, _r, title=name)
        _mn, _mx = ax.get_xlim()
        if min_x is None or _mn < min_x:
            min_x = _mn
        if max_x is None or _mx > max_x:
            max_x = _mx
    if bind_min is not None and min_x < bind_min:
        print('Overriding minimum of %g with bind_min=%g' % (min_x, bind_min))
        min_x = bind_min
    if bind_max is not None and max_x > bind_max:
        print('Overriding maximum of %g with bind_max=%g' % (max_x, bind_max))
        max_x = bind_max
    for ax in axs:
        ax.set_xlim([min_x, max_x])
    axs[-1].set_xlabel('Gear dissipation (kg gear/tonne catch)')
    
    if savefig:
        plt.savefig(title+'.pdf', format='pdf', bbox_inches='tight', transparent=True)

# %%
#results[0][1]['LCI Model-Laso 2017-Deshpande 2020'] = results[0][1].pop('LCI Model-Losa 2018-Deshpande 2020')

# %%
make_gear_model_plot(results, bind_min=2e-8, bind_max=1e3)

# %%
# old make_gear_model_plot(results, bind_min=2e-8)
# Out:
# Overriding minimum of 6.8466e-10 with bind_min=2e-08

# %%
# Run Monte Carlo simulation -- breaking out each stage as a separate dataset
internals = {'effort': defaultdict(list), 'gear': defaultdict(list), 'dissipation': defaultdict(list)}
mmap = dict()
for name, arg in models:
    for m in arg:
        internals['effort'][m.label].extend([m.e_tilde()[1] * m.op_factor for i in range(1000)])
        internals['gear'][m.label].extend([m.g_tilde()[1] * m.scaling_factor for i in range(1000)])
        internals['dissipation'][m.label].extend([m.d_tilde()[1] for i in range(1000)])
        mmap[m.label] = m

# %%
mmap
# Out:
# {'Soldo 2019-Pravin 2016-Gilman 2021': <unit_gears.query.GearModel at 0x7f6f17bca700>,
#  'Soldo 2019-Pravin 2016-Deshpande 2020': <unit_gears.query.GearModel at 0x7f6f17c56910>,
#  'Soldo 2019-Laissane 2011-Gilman 2021': <unit_gears.query.GearModel at 0x7f6f17bca520>,
#  'Soldo 2019-Laissane 2011-Deshpande 2020': <unit_gears.query.GearModel at 0x7f6f17bcad60>,
#  'LCI Model-Laso 2017-Gilman 2021': <unit_gears.query.GearModel at 0x7f6f2b10f400>,
#  'LCI Model-Laso 2017-Deshpande 2020': <unit_gears.query.GearModel at 0x7f6f17bd11c0>,
#  'LCI Model-Avadi 2014-Gilman 2021': <unit_gears.query.GearModel at 0x7f6f17bd1640>,
#  'LCI Model-Avadi 2014-Deshpande 2020': <unit_gears.query.GearModel at 0x7f6f17bd1880>,
#  'Watanabe 2016-Sala 2019-Gilman 2021': <unit_gears.query.GearModel at 0x7f6f17bd1040>,
#  'Watanabe 2016-Sala 2019-Deshpande 2020': <unit_gears.query.GearModel at 0x7f6f17bd1250>,
#  'Watanabe 2016-Gilman 2021': <unit_gears.query.GearModel at 0x7f6f17bd1dc0>,
#  'Watanabe 2016-Deshpande 2020': <unit_gears.query.GearModel at 0x7f6f17bd1c40>,
#  'Surface & Bottom Set Gillnet -Gilman 2021': <unit_gears.query.GearModel at 0x7f6f17bcab20>,
#  'Surface & Bottom Set Gillnet -Deshpande 2020': <unit_gears.query.GearModel at 0x7f6f17c569a0>,
#  'Longlines - pelagic-Gilman 2021': <unit_gears.query.GearModel at 0x7f6f17bcae50>,
#  'Longlines - pelagic-Deshpande 2020': <unit_gears.query.GearModel at 0x7f6f17bcadc0>,
#  'Pelagic gillnets-Gilman 2021': <unit_gears.query.GearModel at 0x7f6f17bcaeb0>,
#  'Pelagic gillnets-Deshpande 2020': <unit_gears.query.GearModel at 0x7f6f17bd1a90>}

# %% [markdown]
# # Manuscript Table 2

# %%
def _p_20_80(_dat):
    j = sorted(_dat)
    l = len(j)
    return j[floor(l*0.2)], j[ceil(l*0.8)]

# %%
def _model_performance(_nam):
    _gt, _rd = next((k, v) for k, v in results if _nam in v)
    fam = mmap[_nam].family
    _ge_nam = fam[0]
    if fam[1] == fam[0]:
        _ge_nam = fam[0]
    else:
        _ge_nam = '%s-%s' % (fam[:2])
    _gt_nam = _gt.split(' ')[0]
    return({
        'Model': _ge_nam,
        'Gear type': _gt_nam,
        'Effort-20-80': '%.3g--%.3g' % _p_20_80(internals['effort'][_nam]),
        'Gear-20-80': '%.3g--%.3g' % _p_20_80(internals['gear'][_nam]),
        'Dissip.': fam[2][0],
        'pct-20-80': '%.3g--%.3g' % tuple(100 * k for k in _p_20_80(internals['dissipation'][_nam])),
        'Result-20-80': '%.3g--%.3g' % _p_20_80(_rd[_nam]),
    })

# %%
table_2 = pd.DataFrame([_model_performance(m) for m in mmap.keys()])

# %%
table_2
# Out:
#                        Model Gear type   Effort-20-80       Gear-20-80  \
# 0     Soldo 2019-Pravin 2016   Seiners    0.135--1.97          15--173
# 1     Soldo 2019-Pravin 2016   Seiners    0.136--2.02        14.7--170
# 2   Soldo 2019-Laissane 2011   Seiners   0.108--0.177         11--16.2
# 3   Soldo 2019-Laissane 2011   Seiners   0.106--0.175       10.9--16.1
# 4        LCI Model-Laso 2017   Seiners           1--1         9.54--13
# 5        LCI Model-Laso 2017   Seiners           1--1        9.7--12.9
# 6       LCI Model-Avadi 2014   Seiners           1--1    0.0711--0.536
# 7       LCI Model-Avadi 2014   Seiners           1--1    0.0712--0.536
# 8    Watanabe 2016-Sala 2019  Trawlers     0.39--5.59      0.323--3.22
# 9    Watanabe 2016-Sala 2019  Trawlers    0.386--5.56      0.319--3.23
# 10             Watanabe 2016  Trawlers   0.356--0.456         548--654
# 11             Watanabe 2016  Trawlers   0.354--0.456         547--649
# 12             Grimaldo 2019   Passive     1.45--8.38  0.00938--0.0106
# 13             Grimaldo 2019   Passive     1.55--9.15  0.00943--0.0106
# 14                 Gabr 2012   Passive     6.87--48.1     0.194--0.414
# 15                 Gabr 2012   Passive     7.16--49.4      0.19--0.411
# 16                Akyol 2012   Passive  0.0811--0.102       26.2--47.1
# 17                Akyol 2012   Passive  0.0815--0.104         26.9--47
#
#    Dissip.    pct-20-80        Result-20-80
# 0        G   2.46--14.2         0.507--3.66
# 1        D  0.454--1.94       0.0884--0.496
# 2        G     2.46--14       0.0414--0.281
# 3        D  0.454--1.95     0.00788--0.0371
# 4        G     2.46--14         0.269--1.61
# 5        D  0.453--1.96       0.0505--0.216
# 6        G   2.44--13.9     0.00518--0.0428
# 7        D  0.446--1.93     0.000928--0.006
# 8        G    3.3--19.3        0.0447--0.32
# 9        D    2.35--3.8      0.0239--0.0848
# 10       G   3.36--19.6          7.96--47.1
# 11       D   2.37--3.83          5.72--9.48
# 12       G   8.01--8.82      0.0012--0.0068
# 13       D  0.822--1.18  0.000152--0.000789
# 14       G    2.11--5.5       0.0552--0.533
# 15       D   3.85--4.91       0.0802--0.612
# 16       G   2.94--3.25       0.0717--0.132
# 17       D   0.811--1.2      0.0238--0.0446

# %%
# old_table_2
# Out:
#                        Model Gear type        Effort-20-80       Gear-20-80  \
# 0     Soldo 2019-Pravin 2016   Seiners         0.135--1.97        15.2--175
# 1     Soldo 2019-Pravin 2016   Seiners         0.132--1.97        14.6--173
# 2   Soldo 2019-Laissane 2011   Seiners        0.109--0.178       10.8--15.9
# 3   Soldo 2019-Laissane 2011   Seiners        0.105--0.176         10.8--16
# 4        LCI Model-Losa 2018   Seiners                1--1         9.61--13
# 5        LCI Model-Losa 2018   Seiners                1--1         9.68--13
# 6       LCI Model-Avadi 2014   Seiners                1--1     0.071--0.536
# 7       LCI Model-Avadi 2014   Seiners                1--1    0.0709--0.535
# 8    Watanabe 2016-Sala 2019  Trawlers         0.391--5.55      0.319--3.17
# 9    Watanabe 2016-Sala 2019  Trawlers         0.387--5.53      0.314--3.21
# 10             Watanabe 2016  Trawlers        0.355--0.455         549--653
# 11             Watanabe 2016  Trawlers         0.36--0.455         548--653
# 12             Grimaldo 2019   Passive           1.42--7.6  0.00943--0.0106
# 13             Grimaldo 2019   Passive          1.62--8.72  0.00942--0.0106
# 14                 Gabr 2012   Passive      0.0289--0.0636   0.0192--0.0209
# 15                 Gabr 2012   Passive      0.0296--0.0643   0.0192--0.0209
# 16                Akyol 2012   Passive  8.28e-05--0.000101       27.3--47.4
# 17                Akyol 2012   Passive  8.37e-05--0.000101       27.4--47.7
#
#    Dissip.    pct-20-80        Result-20-80
# 0        G   2.29--6.67          0.441--1.8
# 1        D  0.449--1.98       0.0902--0.493
# 2        G   2.28--6.65       0.0387--0.138
# 3        D  0.499--1.95     0.00747--0.0363
# 4        G   2.26--6.68        0.249--0.773
# 5        D  0.476--1.94       0.0529--0.216
# 6        G   2.28--6.67     0.00463--0.0202
# 7        D  0.442--1.96   0.000853--0.00602
# 8        G   6.85--17.9       0.0898--0.323
# 9        D   2.38--3.82      0.0226--0.0828
# 10       G   6.89--17.9          16.1--44.3
# 11       D   2.41--3.88          5.55--9.24
# 12       G       8--8.8    0.00125--0.00721
# 13       D  0.822--1.18   0.000147--0.00085
# 14       G  0.482--1.06  3.02e-06--1.07e-05
# 15       D   3.89--4.94  2.41e-05--5.65e-05
# 16       G   2.95--3.25  7.52e-05--0.000132
# 17       D  0.824--1.19  2.29e-05--4.46e-05

# %%
print(table_2.to_latex(index=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
#                     Model & Gear type &   Effort-20-80 &       Gear-20-80 & Dissip. &    pct-20-80 &        Result-20-80 \\
# \midrule
#    Soldo 2019-Pravin 2016 &   Seiners &    0.135--1.97 &          15--173 &       G &   2.46--14.2 &         0.507--3.66 \\
#    Soldo 2019-Pravin 2016 &   Seiners &    0.136--2.02 &        14.7--170 &       D &  0.454--1.94 &       0.0884--0.496 \\
#  Soldo 2019-Laissane 2011 &   Seiners &   0.108--0.177 &         11--16.2 &       G &     2.46--14 &       0.0414--0.281 \\
#  Soldo 2019-Laissane 2011 &   Seiners &   0.106--0.175 &       10.9--16.1 &       D &  0.454--1.95 &     0.00788--0.0371 \\
#       LCI Model-Laso 2017 &   Seiners &           1--1 &         9.54--13 &       G &     2.46--14 &         0.269--1.61 \\
#       LCI Model-Laso 2017 &   Seiners &           1--1 &        9.7--12.9 &       D &  0.453--1.96 &       0.0505--0.216 \\
#      LCI Model-Avadi 2014 &   Seiners &           1--1 &    0.0711--0.536 &       G &   2.44--13.9 &     0.00518--0.0428 \\
#      LCI Model-Avadi 2014 &   Seiners &           1--1 &    0.0712--0.536 &       D &  0.446--1.93 &     0.000928--0.006 \\
#   Watanabe 2016-Sala 2019 &  Trawlers &     0.39--5.59 &      0.323--3.22 &       G &    3.3--19.3 &        0.0447--0.32 \\
#   Watanabe 2016-Sala 2019 &  Trawlers &    0.386--5.56 &      0.319--3.23 &       D &    2.35--3.8 &      0.0239--0.0848 \\
#             Watanabe 2016 &  Trawlers &   0.356--0.456 &         548--654 &       G &   3.36--19.6 &          7.96--47.1 \\
#             Watanabe 2016 &  Trawlers &   0.354--0.456 &         547--649 &       D &   2.37--3.83 &          5.72--9.48 \\
#             Grimaldo 2019 &   Passive &     1.45--8.38 &  0.00938--0.0106 &       G &   8.01--8.82 &      0.0012--0.0068 \\
#             Grimaldo 2019 &   Passive &     1.55--9.15 &  0.00943--0.0106 &       D &  0.822--1.18 &  0.000152--0.000789 \\
#                 Gabr 2012 &   Passive &     6.87--48.1 &     0.194--0.414 &       G &    2.11--5.5 &       0.0552--0.533 \\
#                 Gabr 2012 &   Passive &     7.16--49.4 &      0.19--0.411 &       D &   3.85--4.91 &       0.0802--0.612 \\
#                Akyol 2012 &   Passive &  0.0811--0.102 &       26.2--47.1 &       G &   2.94--3.25 &       0.0717--0.132 \\
#                Akyol 2012 &   Passive &  0.0815--0.104 &         26.9--47 &       D &   0.811--1.2 &      0.0238--0.0446 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Side work

# %% [markdown]
# ## List Quantities

# %%
gml._q
# Out:
# {'catch': <unit_gears.quantities.QuantityGroup at 0x7f6f17c56b80>,
#  'scaling': <unit_gears.quantities.QuantityGroup at 0x7f6f17c56be0>,
#  'operation': <unit_gears.quantities.QuantityGroup at 0x7f6f17c56c40>}

# %%
qs = list(t for k,v in gml._q.items() for t in v.entries)

# %%
for q in qs:
    print('%9s, %50s, %s' % (q.measure, q, q.unit))
# Out:
#     catch,                                  One tonne capture, tC
#     catch,                             One tonne landed catch, t
#   scaling,                       Effort for one tonne capture, t-eff
#   scaling,                  Effort for one tonne landed catch, t-eff
#   scaling,                                    Enclosed volume, m3
#   scaling,                            Gross Tonnage of vessel, GT
#   scaling,                        Kilowatt of engine capacity, kW
#   scaling,                                     Length of line, m-line
#   scaling,                                    Number of hooks, hooks
#   scaling,                                Square meter of net, m2
#   scaling,                            Vessel length in meters, m
#   scaling,                                   kilometer of net, km
# operation,                                   Catch life cycle, vlc
# operation,                                   Day of operation, d
# operation,                                        Fishing day, df
# operation,                                       Fishing hour, hf
# operation,                                      Gear lifetime, glt
# operation,                                           Gear set, set
# operation,                                  Hour of operation, h
# operation,                                  Vessel life cycle, vlt
# operation,                                  Year of operation, yr

# %% [markdown]
# ## List Model Components

# %%
listed_comps = list(set(k for k in gml.gear_models()).union(set(k for k in gml.effort_models()).union(set(k for k in gml.dissipation_models()))))

# %%
# Template code for renaming result sets without re-running simulation
import re

for _, res_dict in results:
    ok = list(filter(lambda x: re.search('Gilman', x), res_dict.keys()))
    nk = [re.sub('Gilman 2020-pre', 'own study', x) for x in ok]
    for i, k in enumerate(ok):
        res_dict[nk[i]] = res_dict.pop(k)

# %%
# Show documentation string
print(listed_comps[0].doc)
# Out:
# source_name: Gilman et al 2021 - Fishing Gear Prioritization
# source_doi: submitted
# source_documentation: Fishing methods with the most problematic risks from abandoned, lost and discarded gear
# Table S1

# %%
# list of families
for f in sorted(set(k.family for k in listed_comps)):
    print(f)
# Out:
# Akyol 2012
# Avadi 2014
# Deshpande 2020
# Gabr 2012
# Gilman 2021
# Grimaldo 2019
# Hoffman 2009
# LCI Model
# Laissane 2011
# Laso 2017
# Pravin 2016
# Sala 2019
# Soldo 2019
# Watanabe 2016
